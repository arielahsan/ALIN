# %% [markdown]
# # tranformasi linier
# tranformasi linier adalah Transformasi linier umum adalah sebuah fungsi yang memetakan suatu ruang vector B ke suatu ruang vector C, sehingga variable A dinyatakan sebagai transformasi linier dari B ke C. Pernyataan tersebut ditunjukkan pada skema
# dibawah ini.:
#
# Jika A : B ke C
#
# Variabel akan disebut sebagai transformasi linier jika semua vector u dan v yang ada
# pada B
# dan semua scalar c, seperti :
#
#  T(u + v) = T(u) + T(v)
#
#  T(cu) = cT(u)

# %% [markdown]
# ## membuktikan bahwa t(u+v) = t(u) + t(v)

# %% [markdown]
# vektor u dan v
# $$
# \mathbf{u}=\binom{1}{2}, \quad \mathbf{v}=\binom{2}{3}
# $$
# - Hitung $\mathbf{u}+\mathbf{v}$ :
# $$
# \mathbf{u}+\mathbf{v}=\binom{1}{2}+\binom{2}{3}=\binom{3}{5}
# $$
# - Terapkan transformasi identitas:
# $$
# T(\mathbf{u}+\mathbf{v})=\mathbf{u}+\mathbf{v}=\binom{3}{5}
# $$
#
# - Hitung $T(\mathbf{u})$ dan $T(\mathbf{v})$ :
# $$
# T(\mathbf{u})=\mathbf{u}=\binom{1}{2}, \quad T(\mathbf{v})=\mathbf{v}=\binom{2}{3}
# $$
# - Jumlahkan hasilnya:
# $$
# T(\mathbf{u})+T(\mathbf{v})=\binom{1}{2}+\binom{2}{3}=\binom{3}{5}
# $$
#
# Terlihat bahwa $T(\mathbf{u}+\mathbf{v})=T(\mathbf{u})+T(\mathbf{v})$.
#
#
# Contoh 2: Transformasi Skalar $k=2$
# Transformasi $T(\mathbf{x})=2 \mathbf{x}$.
# - Vektor $\mathbf{u}$ dan $\mathbf{v}$ :
# $$
# \mathbf{u}=\binom{1}{2}, \quad \mathbf{v}=\binom{2}{3}
# $$
# - Hitung $\mathbf{u}+\mathbf{v}$ :
# $$
# \mathbf{u}+\mathbf{v}=\binom{1}{2}+\binom{2}{3}=\binom{3}{5}
# $$
#
# - Terapkan transformasi skalar:
# $$
# T(\mathbf{u}+\mathbf{v})=2\binom{3}{5}=\binom{6}{10}
# $$
# - Hitung $T(\mathbf{u})$ dan $T(\mathbf{v})$ :
# $$
# T(\mathbf{u})=2\binom{1}{2}=\binom{2}{4}, \quad T(\mathbf{v})=2\binom{2}{3}=\binom{4}{6}
# $$
# - Jumlahkan hasilnya:
# $$
# T(\mathbf{u})+T(\mathbf{v})=\binom{2}{4}+\binom{4}{6}=\binom{6}{10}
# $$
#
# Terlihat bahwa $T(\mathbf{u}+\mathbf{v})=T(\mathbf{u})+T(\mathbf{v})$.
#
# Contoh 3: Rotasi 90 Derajat
# Transformasi rotasi 90 derajat searah jarum jam.
# - Matriks transformasi rotasi 90 derajat:
# $$
# T=\left(\begin{array}{cc}
# 0 & 1 \\
# -1 & 0
# \end{array}\right)
# $$
# - Vektor $\mathbf{u}$ dan $\mathbf{v}$ :
# $$
# \mathbf{u}=\binom{1}{2}, \quad \mathbf{v}=\binom{2}{3}
# $$
# - Hitung $\mathbf{u}+\mathbf{v}$ :
# $$
# \mathbf{u}+\mathbf{v}=\binom{1}{2}+\binom{2}{3}=\binom{3}{5}
# $$
#
# - Terapkan transformasi rotasi:
# $$
# T(\mathbf{u}+\mathbf{v})=\left(\begin{array}{cc}
# 0 & 1 \\
# -1 & 0
# \end{array}\right)\binom{3}{5}=\binom{5}{-3}
# $$
# - Hitung $T(\mathbf{u})$ dan $T(\mathbf{v})$ :
# $$
# \begin{aligned}
# & T(\mathbf{u})=\left(\begin{array}{cc}
# 0 & 1 \\
# -1 & 0
# \end{array}\right)\binom{1}{2}=\binom{2}{-1} \\
# & T(\mathbf{v})=\left(\begin{array}{cc}
# 0 & 1 \\
# -1 & 0
# \end{array}\right)\binom{2}{3}=\binom{3}{-2}
# \end{aligned}
# $$
# - Jumlahkan hasilnya:
# $$
# T(\mathbf{u})+T(\mathbf{v})=\binom{2}{-1}+\binom{3}{-2}=\binom{5}{-3}
# $$
#
# Terlihat bahwa $T(\mathbf{u}+\mathbf{v})=T(\mathbf{u})+T(\mathbf{v})$.
#
# Dari ketiga contoh di atas, kita melihat bagaimana sifat aditivitas $T(\mathbf{u}+\mathbf{v})=T(\mathbf{u})+T(\mathbf{v})$ dipenuhi dalam konteks yang berbeda, memperkuat bahwa $T$ adalah transformasi linier dalam masing-masing kasus.

# %% [markdown]
# ## implementasi dengan code

# %%
import numpy as np

# Definisi vektor u dan v
u = np.array([1, 2])
v = np.array([2, 3])

# Transformasi identitas
def T_identity(x):
    return x

# Hitung T(u + v)
T_u_plus_v = T_identity(u + v)

# Hitung T(u) + T(v)
T_u = T_identity(u)
T_v = T_identity(v)
T_u_plus_T_v = T_u + T_v

print("T(u + v):", T_u_plus_v)
print("T(u) + T(v):", T_u_plus_T_v)
# Out:
# T(u + v): [3 5]
# T(u) + T(v): [3 5]

# %% [markdown]
# # **Tugas**

# %% [markdown]
# Transformasi \( $T$ \) pada vektor-vektor \($(2, 0)$\) dan \($(2, 2)$\) diberikan:
#
#    \[
#    $T(2, 0) = [-2, 0]$
#    \]
#    \[
#    $T(2, 2) = [-2, 2]$
#    \]
#
# ### Langkah-langkah Solusi:
#
# #### 1. Basis Vektor dan Linear:
#
# Untuk menemukan transformasi \( $T$ \), perlu menemukan \( $T$ \) pada basis vektor \( $\mathbf{e}_1$ \) dan \( $\mathbf{e}_2$ \):
#
# \[
# $\mathbf{e}_1 = \begin{pmatrix} 1 \\ 0 \end{pmatrix}, \quad \mathbf{e}_2 = \begin{pmatrix} 0 \\ 1 \end{pmatrix}$
# \]
#
# Kita dapat menuliskan vektor \($\begin{pmatrix} 2 \\ 0 \end{pmatrix}$\) dan \($\begin{pmatrix} 2 \\ 2 \end{pmatrix}$\) sebagai kombinasi linear dari basis vektor:
#
# \[
# $\begin{pmatrix} 2 \\ 0 \end{pmatrix} = 2 \mathbf{e}_1$
# \]
# \[
# $\begin{pmatrix} 2 \\ 2 \end{pmatrix} = 2 \mathbf{e}_1 + 2 \mathbf{e}_2$
# \]
#
# #### 2. Menerapkan Transformasi \( $T$ \) pada Basis Vektor:
#
# \[
# $T(2\mathbf{e}_1) = 2T(\mathbf{e}_1)$
# \]
# \[
# $T(2\mathbf{e}_1 + 2\mathbf{e}_2) = 2T(\mathbf{e}_1) + 2T(\mathbf{e}_2)$
# \]
#
# #### 3. Menggunakan Informasi tadi:
#
# \( $T(2, 0) = [-2, 0]$\), kita bisa menuliskan:
#
# \[
# $T(2\mathbf{e}_1) = \begin{pmatrix} -2 \\ 0 \end{pmatrix}$
# \]
#
# Karena \( $T$ \) adalah linier, kita punya:
#
# \[
# $2T(\mathbf{e}_1) = \begin{pmatrix} -2 \\ 0 \end{pmatrix} \implies T(\mathbf{e}_1) = \begin{pmatrix} -1 \\ 0 \end{pmatrix}$
# \]
#
# Selanjutnya, diberikan \( $T(2, 2) = [-2, 2]$ \):
#
# \[
# $2T(\mathbf{e}_1) + 2T(\mathbf{e}_2) = \begin{pmatrix} -2 \\ 2 \end{pmatrix}$
# \]
#
# Lalu Substitusikan \( $T(\mathbf{e}_1)$ \):
#
# \[
# $2 \begin{pmatrix} -1 \\ 0 \end{pmatrix} + 2T(\mathbf{e}_2) = \begin{pmatrix} -2 \\ 2 \end{pmatrix}$
# \]
#
# \[
# $\begin{pmatrix} -2 \\ 0 \end{pmatrix} + 2T(\mathbf{e}_2) = \begin{pmatrix} -2 \\ 2 \end{pmatrix}$
# \]
#
# \[
# $2T(\mathbf{e}_2) = \begin{pmatrix} 0 \\ 2 \end{pmatrix} \implies T(\mathbf{e}_2) = \begin{pmatrix} 0 \\ 1 \end{pmatrix}$
# \]
#
# #### 4. Membentuk Matriks Transformasi \( $A$ \):
#
# Dengan \( $T(\mathbf{e}_1)$ \) dan \( $T(\mathbf{e}_2$) \), kita bisa bentuk matriks \( $A$ \):
#
# \[
# $A = \begin{pmatrix} T(\mathbf{e}_1) & T(\mathbf{e}_2) \end{pmatrix} = \begin{pmatrix} -1 & 0 \\ 0 & 1 \end{pmatrix}$
# \]
#
# ### Hasil:
#
# Transformasi \( $T$ \) pada basis vektor \( $\mathbf{e}_1$ \) dan \( $\mathbf{e}_2$ \) ditemukan dan matriks \( $A$ \) yang merepresentasikan transformasi linier \( $T$ \) adalah:
#
# \[
# $A = \begin{pmatrix} -1 & 0 \\ 0 & 1 \end{pmatrix}$
# \]

# %% [markdown]
# # **Matriks Refleksi**

# %% [markdown]
# ## Definisi
# Refleksi atau pencerminan dalam konteks transformasi linier merujuk pada suatu transformasi geometri yang "mencerminkan" setiap titik dari suatu objek terhadap suatu garis (di 2D) atau suatu bidang (di 3D), menghasilkan gambar cerminnya. Transformasi ini adalah contoh dari transformasi linier yang dapat direpresentasikan menggunakan matriks.
#
# ### Refleksi di 2D
# Refleksi di bidang dua dimensi dapat dilakukan terhadap sumbu x, sumbu y, garis y = x, atau garis y = -x. Matriks transformasi untuk refleksi tersebut adalah sebagai berikut:
#
# **1. Refleksi terhadap sumbu x**:
#
#    \[
#    $\begin{pmatrix}
#    1 & 0 \\
#    0 & -1
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y) menjadi (x, -y).
#
# **2. Refleksi terhadap sumbu y**:
#
#    \[
#    $\begin{pmatrix}
#    -1 & 0 \\
#    0 & 1
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y) menjadi (-x, y).
#
# **3. Refleksi terhadap garis y = x**:
#
#    \[
#    $\begin{pmatrix}
#    0 & 1 \\
#    1 & 0
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y) menjadi (y, x).
#
# **4. Refleksi terhadap garis y = -x**:
#
#    \[
#    $\begin{pmatrix}
#    0 & -1 \\
#    -1 & 0
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y) menjadi (-y, -x).
#
# ### Refleksi di 3D
# Refleksi di ruang tiga dimensi dilakukan terhadap salah satu bidang koordinat (xy, xz, atau yz). Ada beberapa matriks transformasi untuk refleksi tersebut sebagai berikut:
#
# **1. Refleksi terhadap bidang xy**:
#
#    \[
#    $\begin{pmatrix}
#    1 & 0 & 0 \\
#    0 & 1 & 0 \\
#    0 & 0 & -1
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y, z) menjadi (x, y, -z).
#
# **2. Refleksi terhadap bidang xz**:
#
#    \[
#    $\begin{pmatrix}
#    1 & 0 & 0 \\
#    0 & -1 & 0 \\
#    0 & 0 & 1
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y, z) menjadi (x, -y, z).
#
# **3. Refleksi terhadap bidang yz**:
#
#    \[
#    $\begin{pmatrix}
#    -1 & 0 & 0 \\
#    0 & 1 & 0 \\
#    0 & 0 & 1
#    \end{pmatrix}$
#    \]
#    Mengubah koordinat (x, y, z) menjadi (-x, y, z).

# %% [markdown]
# ### Implementasi dalam Python

# %%
import numpy as np

# Matriks refleksi terhadap sumbu y
reflection_matrix_y = np.array([[-1, 0], [0, 1]])

# Titik yang akan dicerminkan
point = np.array([3, 4])

# Melakukan refleksi
reflected_point = np.dot(reflection_matrix_y, point)

print("Titik asli:", point)
print("Titik hasil refleksi:", reflected_point)
# Out:
# Titik asli: [3 4]
# Titik hasil refleksi: [-3  4]
