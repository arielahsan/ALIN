# %% [markdown]
# # Aljabar Matrix
#
# * Berikan pengertian apa itu Aljabar matrix.
#
# * Buatlah Matrix A(3x3),B(2x3),C(3x2)..
#
# - Operasi Matrix.
# - Penjumlahan.
# - Perkalian.
# - Pengurangan.
# - Tranpose Matrix.
# - Buat program untuk mengkalikan Matrix A dengan Matrix B tidak menggunakan '@'.
#
# Pengertian Matrix: Matrix merupakan suatu kumpulan bilangan sejumlah m x n yang disusun menjadi m baris dan n kolom.

# %%
import numpy as np

# %%
# Matrix
A = np.array([[1,3,9],[3,-2,6],[9,4,1]]) # matrix 3x3
B = np.array([[1,7,5],[2,4,5],[1,-1,4]]) # matrix 3x3
C = np.array([[3,2],[-1,2],[3,5]]) # matrix 3x2
D = np.array([[2,4,8],[2,-1,5],[-8,5,2]]) # matrix 3x3
E = (A+B)
F = 2*(A)
G = A @ C

# %%
print(f"Matrix A 3x3: \n{A}")
print(f" Matrix B 3x3: \n{B}")
print(f"Matrix C 3x2: \n{C}")
print(f"Matrix D 3x3: \n{D}")
# Out:
# Matrix A 3x3:
# [[ 1  3  9]
#  [ 3 -2  6]
#  [ 9  4  1]]
#  Matrix B 3x3:
# [[ 1  7  5]
#  [ 2  4  5]
#  [ 1 -1  4]]
# Matrix C 3x2:
# [[ 3  2]
#  [-1  2]
#  [ 3  5]]
# Matrix D 3x3:
# [[ 2  4  8]
#  [ 2 -1  5]
#  [-8  5  2]]

# %% [markdown]
# #Operasi Penjumlahan Matrix
# Penjumlahan matriks adalah operasi penjumlahan dua matriks dengan menjumlahkan komponen-komponennya yang seletak.Dua matriks dapat dijumlahkan jika jumlah baris dan kolomnya sama. Matriks hasil penjumlahannya juga akan memiliki ordo yang sama.

# %%
# Matrix A+B
E = (A+B)
print(f"Matrix E =\n{E}")
# Out:
# Matrix E =
# [[ 2 10 14]
#  [ 5  2 11]
#  [10  3  5]]

# %% [markdown]
# #Operasi Perkalian Matrix
# perkalian matriks adalah suatu operasi biner yang menghasilkan suatu matriks dari dua matriks dengan entri dalam suatu medan, atau secara lebih umum dalam suatu gelanggang atau bahkan suatu semigelanggang.

# %%
F = 2*(A)

print(f"Perkalian 2 * Matrix F =\n{F}")
# Out:
# Perkalian 2 * Matrix F =
# [[ 2  6 18]
#  [ 6 -4 12]
#  [18  8  2]]

# %%
# Matrix A x C
G = A @ C
print(f"Matrix G =\n{G}")
print(f"Ukuran Matrix = {G.shape}")
# Out:
# Matrix G =
# [[27 53]
#  [29 32]
#  [26 31]]
# Ukuran Matrix = (3, 2)

# %% [markdown]
# #Operasi Pengurangan Matrix
# Konsep pengurangan pada matriks sama seperti penjumlahan, yaitu mengurangkan elemen yang letaknya sama atau seletak.

# %%
# Matrix A - B
H  = A - B
print(f"Matrix G =\n{H}")
# Out:
# Matrix G =
# [[ 0 -4  4]
#  [ 1 -6  1]
#  [ 8  5 -3]]

# %% [markdown]
# #Cek Persamaan
# Sistem persamaan matriks adalah kumpulan persamaan yang terdiri dari matriks koefisien, matriks variabel, dan vektor konstanta.
#
# Matrix A(BxC) = Matrix (AxB)C

# %%
Matrix1 = A @ (B @ C)
Matrix2 = (A @ B) @ C
Matrix1 == Matrix2
# Out:
# array([[ True,  True],
#        [ True,  True],
#        [ True,  True]])

# %% [markdown]
# Matrix c(AB) = Matrix (cA)B = Matrix A(cB)

# %%
c = 2
Matrix_3 = c * (A @ B)
Matrix_4 = (c * A) @ B
Matrix_5 = A @ (c * B)
print(Matrix_3)
print()
print(Matrix_4)
print()
print(Matrix_5)
# Out:
# [[ 32  20 112]
#  [ 10  14  58]
#  [ 36 156 138]]
#
# [[ 32  20 112]
#  [ 10  14  58]
#  [ 36 156 138]]
#
# [[ 32  20 112]
#  [ 10  14  58]
#  [ 36 156 138]]

# %% [markdown]
# #Tranpose Matrix
# Transpose matriks adalah matriks baru yang diperoleh dengan cara menukar elemen-elemen baris menjadi elemen kolom atau sebaliknya.
#
# Anggap Baris = m, Kolom = n
#
# => C = A_trans @ A
#
# => (n x m) @ (m x n) = n * n
#
# contoh: [2 x 3] @ [3 x 2] = [2 x 2]
#
# => C = A @ A_trans
#
# => (m x n) @ (n x m) = m x m
#
# contoh: [3 x 2] @ [2 x 3] = [3 x 3]

# %%
# Contoh dengan Martrix 3x3

A_tran = A.transpose()
print('Matrik A sebelum di transpose=\n', A)
print()
print('Matrik A setelah di transpose=\n',A_tran)
print('Ordo A_transpose adalah',A_tran.shape)
print()
Z = A_tran @ A
print('Z = A_transpose x A =\n',Z)
print('Ordo Z adalah',Z.shape)
print()
P=A @ A_tran
print('P = A_transpose x A =\n',P)
print('Ordo P adalah',P.shape)
# Out:
# Matrik A sebelum di transpose=
#  [[ 1  3  9]
#  [ 3 -2  6]
#  [ 9  4  1]]
#
# Matrik A setelah di transpose=
#  [[ 1  3  9]
#  [ 3 -2  4]
#  [ 9  6  1]]
# Ordo A_transpose adalah (3, 3)
#
# Z = A_transpose x A =
#  [[ 91  33  36]
#  [ 33  29  19]
#  [ 36  19 118]]
# Ordo Z adalah (3, 3)
#
# P = A_transpose x A =
#  [[91 51 30]
#  [51 49 25]
#  [30 25 98]]
# Ordo P adalah (3, 3)

# %%
# Soal dengan Matrix 3x2

Matrix_A = np.array([[-1,2,3],[3,2,1]])

Matrix_A_Trans = Matrix_A.transpose()
print('Matrix_A sebelum di transpose=\n', Matrix_A)
print()

print('Matrix A setelah di transpose=\n',Matrix_A_Trans)
print('Ordo Matrix_A_Transpose adalah',Matrix_A_Trans.shape)
print()

Matrix_Z = Matrix_A_Trans @ Matrix_A
print('Matrix_Z = Matrix_A_Transpose x Matrix_A =\n',Matrix_Z)
print('Ordo Z adalah',Z.shape)
print()

Matrix_P = Matrix_A @ Matrix_A_Trans
print('P = A_transpose x A =\n',Matrix_P)
print('ordo Matrix P adalah',Matrix_P.shape)
# Out:
# Matrix_A sebelum di transpose=
#  [[-1  2  3]
#  [ 3  2  1]]
#
# Matrix A setelah di transpose=
#  [[-1  3]
#  [ 2  2]
#  [ 3  1]]
# Ordo Matrix_A_Transpose adalah (3, 2)
#
# Matrix_Z = Matrix_A_Transpose x Matrix_A =
#  [[10  4  0]
#  [ 4  8  8]
#  [ 0  8 10]]
# Ordo Z adalah (3, 3)
#
# P = A_transpose x A =
#  [[14  4]
#  [ 4 14]]
# ordo Matrix P adalah (2, 2)

# %% [markdown]
# #Program untuk mengkalikan Matrix A dengan Matrix B Secara Manual tidak menggunakan ‘@’

# %%
Matrix_1 = [[3,2,4],
            [7,-4,3],
            [5,3,2]]

Matrix_2 = [[2,3,6],
            [4,3,6],
            [4,-6,2]]

print(f" Matrix_1 = {Matrix_1}")
print()
print(f" Matrix_2 = {Matrix_2}")

def multiply_matrix(matrix1,matrix2):
  result = [[0,0,0],[0,0,0],[0,0,0]] # Menginisialisasikan dulu matrix dengan semua value 0

  for i in range(len(Matrix_1)):
    for j in range(len(Matrix_2[0])):
      for k in range(len(Matrix_2)):
        result[i][j] += Matrix_1[i][k] * Matrix_2[k][j]
  return result

hasil = multiply_matrix(Matrix_1,Matrix_2)
print()
print(f"Hasil perkalian Matrix_1 dan Matrix 2 = {hasil}")
print()
print(f"Pembuktian untuk Matrix A @ B =\n{A @ B}")
# Out:
#  Matrix_1 = [[3, 2, 4], [7, -4, 3], [5, 3, 2]]
#
#  Matrix_2 = [[2, 3, 6], [4, 3, 6], [4, -6, 2]]
#
# Hasil perkalian Matrix_1 dan Matrix 2 = [[30, -9, 38], [10, -9, 24], [30, 12, 52]]
#
# Pembuktian untuk Matrix A @ B =
# [[16 10 56]
#  [ 5  7 29]
#  [18 78 69]]

# %%
# Ini yang menggunakan numpy array

print(f" Matrix_1 = \n{A}")
print()
print(f" Matrix_2 = \n{B}")

def multiply_matrix(matrix1,matrix2):
  result = [[0,0,0],[0,0,0],[0,0,0]] # Menginisialisasikan dulu matrix dengan semua value 0

  for i in range(len(A)):
    for j in range(len(B[0])):
      for k in range(len(B)):
        result[i][j] += A[i][k] * B[k][j]
  return result

hasil = multiply_matrix(A,B)
print()
print(f"Hasil perkalian Matrix_1 dan Matrix 2 = {hasil}")
print()
print(f"Pembuktian untuk Matrix A @ B =\n{A @ B}")
# Out:
#  Matrix_1 =
# [[ 1  3  9]
#  [ 3 -2  6]
#  [ 9  4  1]]
#
#  Matrix_2 =
# [[ 1  7  5]
#  [ 2  4  5]
#  [ 1 -1  4]]
#
# Hasil perkalian Matrix_1 dan Matrix 2 = [[16, 10, 56], [5, 7, 29], [18, 78, 69]]
#
# Pembuktian untuk Matrix A @ B =
# [[16 10 56]
#  [ 5  7 29]
#  [18 78 69]]
