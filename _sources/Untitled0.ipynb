# %%
import numpy as np
A = np.array ([[1,2,3],[3,4,5],[4,5,6]])
B = np.array ([[2,3,4],[4,5,6]])
hasil = np.dot (A,B)
print(hasil)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9c69059c4c3b> in <cell line: 4>()
#       2 A = np.array ([[1,2,3],[3,4,5],[4,5,6]])
#       3 B = np.array ([[2,3,4],[4,5,6]])
# ----> 4 hasil = np.dot (A,B)
#       5 print(hasil)
#
# ValueError: shapes (3,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-879122a0bab2> in <cell line: 1>()
# ----> 1 hasil = np.dot(A,B)
#       2 print (hasil)
#
# ValueError: shapes (3,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)
